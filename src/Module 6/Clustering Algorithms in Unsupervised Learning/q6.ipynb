# %%
# Question 5: Evaluating Clustering with Silhouette Score
# Description: Use Silhouette Score to evaluate the quality of clustering produced by K-Means. Experiment with different numbers of clusters.

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

sil_scores = []
K_range = range(2, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    score = silhouette_score(X, kmeans.labels_)
    sil_scores.append(score)

plt.figure(figsize=(8, 6))
plt.plot(K_range, sil_scores, marker='o', linestyle='-', color='b')
plt.title("Silhouette Score for Different k")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.grid(True)
plt.show()

# Optionally, you can print the best score and optimal k
optimal_k = K_range[np.argmax(sil_scores)]
best_score = max(sil_scores)
print(f"Optimal number of clusters: {optimal_k} with Silhouette Score: {best_score:.4f}")
# Out:
# Optimal number of clusters: 4 with Silhouette Score: 0.6820
