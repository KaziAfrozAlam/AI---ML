# %%
# Question 6: Construct a Custom Dendrogram for Better Insights
# Description: Build a custom dendrogram with annotated thresholds to determine optimal cluster number.

import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.datasets import make_blobs

X, _ = make_blobs(n_samples=100, centers=4, cluster_std=1.0, random_state=42)

Z = linkage(X, method='ward')

plt.figure(figsize=(12, 6))
dendrogram(Z, leaf_rotation=90., leaf_font_size=10)

threshold = 15
plt.axhline(y=threshold, color='red', linestyle='--', label=f'Threshold = {threshold}')
plt.title('Custom Dendrogram with Threshold')
plt.xlabel('Sample Index or (Cluster Size)')
plt.ylabel('Distance')
plt.legend()
plt.show()

cluster_labels = fcluster(Z, t=threshold, criterion='distance')
print("Cluster labels:", cluster_labels)
# Out:
# Cluster labels: [4 1 3 1 4 1 2 2 2 3 3 1 1 2 3 4 4 2 4 4 3 4 4 2 2 3 2 4 4 1 1 2 1 4 3 3 3
#  3 2 2 4 2 1 3 3 1 1 4 4 2 2 2 2 1 4 4 3 3 2 3 1 2 4 1 4 4 1 4 2 1 2 1 4 3
#  1 4 1 4 1 1 2 1 3 4 3 3 3 1 3 2 2 1 3 1 3 3 3 2 4 2]
