# %% [markdown]
# Question 2: Introduction to Regularization with Ridge Regression<br>
# Task: Use Ridge regression on a noisy dataset and evaluate improvements over simple linear
# regression due to regularization.

# %%
# Write your code here
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

np.random.seed(0)
X = np.linspace(0, 10, 100).reshape(-1, 1)
y = 2 * X.flatten() + 1 + np.random.normal(0, 5, size=X.shape[0]) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
y_pred_linear = linear_model.predict(X_test)

ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
y_pred_ridge = ridge_model.predict(X_test)

mse_linear = mean_squared_error(y_test, y_pred_linear)
mse_ridge = mean_squared_error(y_test, y_pred_ridge)

print(f"Mean Squared Error (Linear Regression): {mse_linear:.2f}")
print(f"Mean Squared Error (Ridge Regression): {mse_ridge:.2f}")

plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='black', label='Test Data')
plt.plot(X_test, y_pred_linear, label='Linear Regression', color='blue')
plt.plot(X_test, y_pred_ridge, label='Ridge Regression', color='red')
plt.title("Linear vs Ridge Regression on Noisy Data")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error (Linear Regression): 23.98
# Mean Squared Error (Ridge Regression): 23.98
