# %% [markdown]
# Question 1: Load a CSV file containing a dataset into a Pandas DataFrame. Display the first few rows to understand its basic structure.

# %%
# Write your code from here
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)
df = pd.DataFrame({
    'price': np.random.normal(100, 20, 100),
    'quantity': np.random.randint(1, 50, 100),
    'rating': np.random.uniform(1.0, 5.0, 100),
    'category': np.random.choice(['A', 'B', 'C'], size=100)
})

df.loc[5:10, 'price'] = np.nan
df.loc[20:25, 'rating'] = np.nan

df = pd.concat([df, df.iloc[0:3]], ignore_index=True)

print("First 5 rows of dataset:")
print(df.head())
# Out:
# First 5 rows of dataset:
#         price  quantity    rating category
# 0  109.934283         9  2.618033        C
# 1   97.234714        37  4.551080        B
# 2  112.953771        33  4.403714        A
# 3  130.460597        42  4.742540        B
# 4   95.316933        44  4.141363        C

# %% [markdown]
# Question 2: Determine the number of rows and columns in the dataset.

# %%
# Write your code from here
print(f"\nShape of dataset: {df.shape}")
# Out:
# Shape of dataset: (103, 4)

# %% [markdown]
# Question 3: Identify the data type of each column in the dataset.

# %%
# Write your code from here
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# price       float64
# quantity      int64
# rating      float64
# category     object
# dtype: object

# %% [markdown]
# Question 4: Generate summary statistics for the numerical columns in the dataset.

# %%
# Write your code from here
print("\nSummary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#             price    quantity     rating
# count   97.000000  103.000000  97.000000
# mean    97.711198   24.611650   3.018248
# std     18.059899   14.882041   1.180185
# min     47.605098    1.000000   1.020739
# 25%     87.965868   11.000000   2.118241
# 50%     97.687034   25.000000   2.879778
# 75%    107.513960   37.000000   4.141363
# max    137.045564   49.000000   4.978202

# %% [markdown]
# Question 5: Identify columns with missing values and count the number of missing values in each.

# %%
# Write your code from here
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# price       6
# quantity    0
# rating      6
# category    0
# dtype: int64

# %% [markdown]
# Question 6: Replace missing values in a column with the median value of that column.

# %%
# Write your code from here
df['price'] = df['price'].fillna(df['price'].median())

# %% [markdown]
# Question 7: Remove duplicate rows from the dataset.

# %%
# Write your code from here
df = df.drop_duplicates()
print(f"\nShape after removing duplicates: {df.shape}")
# Out:
# Shape after removing duplicates: (100, 4)

# %% [markdown]
# Question 8: Create a histogram to visualize the distribution of a numerical column (e.g., 'price').

# %%
# Write your code from here
sns.histplot(df['price'], bins=20, kde=True)
plt.title('Histogram of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Question 9: Create a scatter plot to visualize the relationship between two numerical variables

# %%
# Write your code from here
sns.scatterplot(x='price', y='quantity', data=df)
plt.title('Scatter Plot: Price vs Quantity')
plt.xlabel('Price')
plt.ylabel('Quantity')
plt.show()

# %% [markdown]
# Question 10: Visualize the correlation matrix of the dataset using a heatmap.

# %%
# Write your code from here
plt.figure(figsize=(8, 5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
